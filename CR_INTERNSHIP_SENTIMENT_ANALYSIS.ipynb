# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakash-S-Raj/Coding-Raja-Technologies-Internship-Task-1-Machine-Learning-/blob/main/CR_INTERNSHIP_SENTIMENT_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import plotly.express as pe

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import warnings

# %%
df=pd.read_csv('/content/drive/MyDrive/chat_dataset.csv')
df.head(3)
# Out:
#                               message sentiment
# 0          I really enjoyed the movie  positive
# 1               The food was terrible  negative
# 2  I'm not sure how I feel about this   neutral

# %%
df2 = df.applymap(lambda x: re.sub(r'[^\x00-\x7F]+', '', x))

# %%
df2.head(330)
# Out:
#                                    message sentiment
# 0               I really enjoyed the movie  positive
# 1                    The food was terrible  negative
# 2       I'm not sure how I feel about this   neutral
# 3                The service was excellent  positive
# 4                   I had a bad experience  negative
# ..                                     ...       ...
# 325       I'm so glad I made this purchase  positive
# 326  The food at the wedding was delicious  positive
# 327                      Hey.. what's up?    neutral
# 328                     I'm feeling so-so    neutral
# 329                 Thanks for your help!    neutral
#
# [330 rows x 2 columns]

# %%
df.shape
# Out:
# (584, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   message    584 non-null    object
#  1   sentiment  584 non-null    object
# dtypes: object(2)
# memory usage: 9.2+ KB

# %%
for i in range(3):
    print("Message: ", [i])
    print(df2['message'].iloc[i], "\n")
    print("Sentiment: ", df['sentiment'].iloc[i], "\n\n")
# Out:
# Message:  [0]
# I really enjoyed the movie
#
# Sentiment:  positive
#
#
# Message:  [1]
# The food was terrible
#
# Sentiment:  negative
#
#
# Message:  [2]
# I'm not sure how I feel about this
#
# Sentiment:  neutral

# %%
df2.groupby(['sentiment'])[['sentiment']].count()
# Out:
#            sentiment
# sentiment
# negative         147
# neutral          259
# positive         178

# %%
def no_of_words(text):
    words= text.split()
    word_count = len(words)
    return word_count

# %%
df2['word_count'] = df2['message'].apply(no_of_words)

# %%
df2.head(10)
# Out:
#                               message sentiment  word_count
# 0          I really enjoyed the movie  positive           5
# 1               The food was terrible  negative           4
# 2  I'm not sure how I feel about this   neutral           8
# 3           The service was excellent  positive           4
# 4              I had a bad experience  negative           5
# 5             This is a great product  positive           5
# 6           I wouldn't recommend this  negative           4
# 7             The price is a bit high   neutral           6
# 8        The weather is perfect today  positive           5
# 9             The traffic is horrible  negative           4

# %%
fig, ax = plt.subplots(1,2, figsize=(10,6))
ax[0].hist(df2[df2['sentiment'] == 'positive']['word_count'], label='Positive', color='blue', rwidth=0.8);
ax[1].hist(df2[df2['sentiment'] == 'negative']['word_count'], label='Negative', color='red', rwidth=0.8);

ax[0].legend(loc='right');
ax[1].legend(loc='right');
ax[0].set(xlabel="positive", ylabel="word_count");
ax[1].set(xlabel="negative", ylabel="word_count");
fig.suptitle("Number of words in message")
plt.show()

# %%
df2.sentiment.replace("positive", 1, inplace=True)
df2.sentiment.replace("negative", 0, inplace=True)
df2.sentiment.replace("neutral", 2, inplace=True)

# %%
df2.head(3)
# Out:
#                               message  sentiment  word_count
# 0          I really enjoyed the movie          1           5
# 1               The food was terrible          0           4
# 2  I'm not sure how I feel about this          2           8

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
def stopw(mes):
  mes=BeautifulSoup(mes).get_text()
  mes=mes.lower()
  mes=re.sub("[^a-zA-Z]",' ',mes)
  mes=re.sub(r"https\S+|www\S+|http\S+", '', mes, flags = re.MULTILINE)
  mes=re.sub(r'\@w+|\#', '', mes)
  mes=re.sub(r'[^\w\s]', '', mes)
  tok_mes=word_tokenize(mes)
  filtered_mes=[w for w in tok_mes if not w in stop_words]
  return " ".join(filtered_mes)

# %%
df2.message = df2['message'].apply(stopw)
# Out:
# <ipython-input-19-db3c02d2d482>:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   mes=BeautifulSoup(mes).get_text()

# %%
duplicatecount = df2.duplicated().sum()
print("Number of duplicate entries: ", duplicatecount)
# Out:
# Number of duplicate entries:  48

# %%
df3 = df2.drop_duplicates('message')

# %%
df3.head(3)
# Out:
#                 message  sentiment  word_count
# 0  really enjoyed movie          1           5
# 1         food terrible          0           4
# 2             sure feel          2           8

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524 entries, 0 to 583
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   message     524 non-null    object
#  1   sentiment   524 non-null    int64
#  2   word_count  524 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 16.4+ KB

# %%
stemmer = PorterStemmer()
def stemming(data):
    text = [stemmer.stem(word) for word in data]
    return ''.join(text)
df3.message = df3['message'].apply(lambda x: stemming(x))
# Out:
# <ipython-input-25-ccd54ecd4b84>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.message = df3['message'].apply(lambda x: stemming(x))

# %%
print(df3.message)
# Out:
# 0                                   really enjoyed movie
# 1                                          food terrible
# 2                                              sure feel
# 3                                      service excellent
# 4                                         bad experience
#                              ...
# 578    got parking ticket doctor office even though p...
# 579                  cancel vacation plans get time work
# 580                computer crashed lost important files
# 582                 cold stop coughing really hard sleep
# 583         found ex dating someone new feel heartbroken
# Name: message, Length: 524, dtype: object

# %%
df3['new_word_count'] = df3['message'].apply(no_of_words)
df3.head(400)
# Out:
# <ipython-input-27-2d5cbc9de4c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['new_word_count'] = df3['message'].apply(no_of_words)
#                            message  sentiment  word_count  new_word_count
# 0             really enjoyed movie          1           5               3
# 1                    food terrible          0           4               2
# 2                        sure feel          2           8               2
# 3                service excellent          1           4               2
# 4                   bad experience          0           5               2
# ..                             ...        ...         ...             ...
# 453      grateful good things life          1          10               4
# 454  got surprise visit old friend          1          10               5
# 455  love trying new foods flavors          1           7               5
# 456        amazing date last night          1           7               4
# 457     proud accomplishments year          1           8               3
#
# [400 rows x 4 columns]

# %%
positive_messages =  df3[df3.sentiment == 1]
positive_messages.head(3)
# Out:
#                 message  sentiment  word_count  new_word_count
# 0  really enjoyed movie          1           5               3
# 3     service excellent          1           4               2
# 5         great product          1           5               2

# %%
negative_messages =  df3[df3.sentiment == 0]
negative_messages.head(3)
# Out:
#           message  sentiment  word_count  new_word_count
# 1   food terrible          0           4               2
# 4  bad experience          0           5               2
# 6       recommend          0           4               1

# %%
neutral_messages =  df3[df3.sentiment == 2]
neutral_messages.head(3)
# Out:
#             message  sentiment  word_count  new_word_count
# 2         sure feel          2           8               2
# 7    price bit high          2           6               3
# 10  feeling neutral          2           5               2

# %%
from collections import Counter
countp = Counter()
for text in positive_messages['message'].values:
    for word in text.split():
        countp[word] +=1
countp.most_common(15)
# Out:
# [('love', 18),
#  ('new', 15),
#  ('great', 12),
#  ('grateful', 12),
#  ('feeling', 12),
#  ('amazing', 11),
#  ('happy', 10),
#  ('service', 9),
#  ('hotel', 9),
#  ('life', 9),
#  ('time', 8),
#  ('loving', 8),
#  ('excellent', 7),
#  ('product', 7),
#  ('today', 7)]

# %%
countn=Counter()
for text in negative_messages['message'].values:
    for word in text.split():
        countn[word] +=1
countn.most_common(30)
# Out:
# [('hate', 14),
#  ('got', 13),
#  ('feeling', 12),
#  ('terrible', 11),
#  ('product', 11),
#  ('service', 6),
#  ('movie', 6),
#  ('car', 6),
#  ('going', 6),
#  ('bad', 5),
#  ('hotel', 5),
#  ('boring', 5),
#  ('work', 5),
#  ('tired', 5),
#  ('lost', 5),
#  ('food', 4),
#  ('regret', 4),
#  ('restaurant', 4),
#  ('time', 4),
#  ('today', 4),
#  ('software', 4),
#  ('company', 4),
#  ('stressed', 4),
#  ('life', 4),
#  ('someone', 4),
#  ('like', 4),
#  ('things', 4),
#  ('traffic', 3),
#  ('awful', 3),
#  ('poor', 3)]

# %%
countne=Counter()
for text in neutral_messages['message'].values:
    for word in text.split():
        countne[word] +=1
countne.most_common(30)
# Out:
# [('sure', 29),
#  ('feeling', 28),
#  ('bit', 23),
#  ('average', 20),
#  ('today', 15),
#  ('standard', 15),
#  ('trying', 12),
#  ('regular', 9),
#  ('service', 8),
#  ('hotel', 8),
#  ('right', 8),
#  ('make', 7),
#  ('time', 7),
#  ('work', 7),
#  ('really', 6),
#  ('strong', 6),
#  ('movie', 6),
#  ('okay', 6),
#  ('phone', 6),
#  ('weather', 6),
#  ('ordinary', 6),
#  ('care', 5),
#  ('way', 5),
#  ('food', 5),
#  ('scenery', 5),
#  ('traffic', 5),
#  ('stay', 5),
#  ('need', 5),
#  ('know', 4),
#  ('feelings', 4)]

# %%
neutral_words = pd.DataFrame(countne.most_common(15))
neutral_words.columns = ['word', 'count']
neutral_words.head(5)
# Out:
#       word  count
# 0     sure     29
# 1  feeling     28
# 2      bit     23
# 3  average     20
# 4    today     15

# %%
negative_words = pd.DataFrame(countn.most_common(15))
negative_words.columns = ['word', 'count']
negative_words.head(5)
# Out:
#        word  count
# 0      hate     14
# 1       got     13
# 2   feeling     12
# 3  terrible     11
# 4   product     11

# %%
import plotly.express as px

# %%
positive_words = pd.DataFrame(countp.most_common(15))
positive_words.columns = ['word', 'count']
positive_words.head(5)
# Out:
#        word  count
# 0      love     18
# 1       new     15
# 2     great     12
# 3  grateful     12
# 4   feeling     12

# %%
px.bar(positive_words, x='count', y='word', title='Common words in positive messages', color = 'word')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="312aa2ee-2269-498c-a72a-19a2bba1278d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("312aa2ee-2269-498c-a72a-19a2bba1278d")) {                    Plotly.newPlot(                        "312aa2ee-2269-498c-a72a-19a2bba1278d",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"love","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"love","offsetgroup":"love","orientation":"h","showlegend":true,"textposition":"auto","x":[18],"xaxis":"x","y":["love"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"new","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"new","offsetgroup":"new","orientation":"h","showlegend":true,"textposition":"auto","x":[15],"xaxis":"x","y":["new"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"great","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"great","offsetgroup":"great","orientation":"h","showlegend":true,"textposition":"auto","x":[12],"xaxis":"x","y":["great"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"grateful","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"grateful","offsetgroup":"grateful","orientation":"h","showlegend":true,"textposition":"auto","x":[12],"xaxis":"x","y":["grateful"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feeling","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"feeling","offsetgroup":"feeling","orientation":"h","showlegend":true,"textposition":"auto","x":[12],"xaxis":"x","y":["feeling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"amazing","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"amazing","offsetgroup":"amazing","orientation":"h","showlegend":true,"textposition":"auto","x":[11],"xaxis":"x","y":["amazing"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"happy","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"happy","offsetgroup":"happy","orientation":"h","showlegend":true,"textposition":"auto","x":[10],"xaxis":"x","y":["happy"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[9],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hotel","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"hotel","offsetgroup":"hotel","orientation":"h","showlegend":true,"textposition":"auto","x":[9],"xaxis":"x","y":["hotel"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"life","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"life","offsetgroup":"life","orientation":"h","showlegend":true,"textposition":"auto","x":[9], ...

# %%
px.bar(negative_words, x='count', y='word', title='Common words in negative messages', color = 'word')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="080a2075-eef5-416a-89f6-32e14dcd7bba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("080a2075-eef5-416a-89f6-32e14dcd7bba")) {                    Plotly.newPlot(                        "080a2075-eef5-416a-89f6-32e14dcd7bba",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"hate","offsetgroup":"hate","orientation":"h","showlegend":true,"textposition":"auto","x":[14],"xaxis":"x","y":["hate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"got","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"got","offsetgroup":"got","orientation":"h","showlegend":true,"textposition":"auto","x":[13],"xaxis":"x","y":["got"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feeling","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"feeling","offsetgroup":"feeling","orientation":"h","showlegend":true,"textposition":"auto","x":[12],"xaxis":"x","y":["feeling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"terrible","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"terrible","offsetgroup":"terrible","orientation":"h","showlegend":true,"textposition":"auto","x":[11],"xaxis":"x","y":["terrible"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"product","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"product","offsetgroup":"product","orientation":"h","showlegend":true,"textposition":"auto","x":[11],"xaxis":"x","y":["product"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"movie","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"movie","offsetgroup":"movie","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["movie"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"car","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"car","offsetgroup":"car","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["car"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"going","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"going","offsetgroup":"going","orientation":"h","showlegend":true,"textposition":"auto","x":[6],"xaxis":"x","y":["going"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bad","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"bad","offsetgroup":"bad","orientation":"h","showlegend":true,"textposition":"auto","x":[5],"xaxis":"x"," ...

# %%
px.bar(neutral_words, x='count', y='word', title='Common words in neutral messages', color = 'word')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e549999-0cf4-4c40-9f8b-a0155b1cc71f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e549999-0cf4-4c40-9f8b-a0155b1cc71f")) {                    Plotly.newPlot(                        "8e549999-0cf4-4c40-9f8b-a0155b1cc71f",                        [{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"sure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sure","offsetgroup":"sure","orientation":"h","showlegend":true,"textposition":"auto","x":[29],"xaxis":"x","y":["sure"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feeling","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"feeling","offsetgroup":"feeling","orientation":"h","showlegend":true,"textposition":"auto","x":[28],"xaxis":"x","y":["feeling"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bit","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bit","offsetgroup":"bit","orientation":"h","showlegend":true,"textposition":"auto","x":[23],"xaxis":"x","y":["bit"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"average","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"average","offsetgroup":"average","orientation":"h","showlegend":true,"textposition":"auto","x":[20],"xaxis":"x","y":["average"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"today","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"today","offsetgroup":"today","orientation":"h","showlegend":true,"textposition":"auto","x":[15],"xaxis":"x","y":["today"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"standard","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"standard","offsetgroup":"standard","orientation":"h","showlegend":true,"textposition":"auto","x":[15],"xaxis":"x","y":["standard"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"trying","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"trying","offsetgroup":"trying","orientation":"h","showlegend":true,"textposition":"auto","x":[12],"xaxis":"x","y":["trying"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"regular","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"regular","offsetgroup":"regular","orientation":"h","showlegend":true,"textposition":"auto","x":[9],"xaxis":"x","y":["regular"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"service","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"service","offsetgroup":"service","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["service"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"word=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hotel","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"hotel","offsetgroup":"hotel","orientation":"h","showlegend":true,"textposition": ...

# %%
X=df3['message']
Y=df3['sentiment']

# %%
X.head(3)
# Out:
# 0    really enjoyed movie
# 1           food terrible
# 2               sure feel
# Name: message, dtype: object

# %%
Y.head(3)
# Out:
# 0    1
# 1    0
# 2    2
# Name: sentiment, dtype: int64

# %%
vectobject=TfidfVectorizer()
X=vectobject.fit_transform(df3['message'])

# %%
X
# Out:
# <524x585 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1641 stored elements in Compressed Sparse Row format>

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=20,shuffle=True,stratify=Y)

# %%
print(X_train[6],y_train[6])
# Out:
#   (0, 365)	0.41047918703703107
#   (0, 332)	0.34184292435984726
#   (0, 15)	0.36717452674004963
#   (0, 558)	0.3851475846568287
#   (0, 571)	0.3851475846568287
#   (0, 70)	0.3851475846568287
#   (0, 64)	0.36717452674004963 0

# %%
print(X_test[6])
# Out:
#   (0, 39)	0.7071067811865476
#   (0, 10)	0.7071067811865476

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (393, 585) (131, 585) (393,) (131,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

# %%
model=LogisticRegression()
model2=LinearSVC()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model2.fit(X_train,y_train)
# Out:
# LinearSVC()

# %%
model.score(X_test,y_test)
# Out:
# 0.7786259541984732

# %%
model2.score(X_test,y_test)
# Out:
# 0.7938931297709924

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']},
              {'penalty':['none', 'elasticnet', 'l1', 'l2']},
              {'C':[0.001, 0.01, 0.1, 1, 10, 100]}]
grid = GridSearchCV(model, param_grid, refit=True, verbose = 3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ..................solver=newton-cg;, score=0.797 total time=   0.0s
# [CV 2/5] END ..................solver=newton-cg;, score=0.772 total time=   0.0s
# [CV 3/5] END ..................solver=newton-cg;, score=0.835 total time=   0.0s
# [CV 4/5] END ..................solver=newton-cg;, score=0.782 total time=   0.0s
# [CV 5/5] END ..................solver=newton-cg;, score=0.679 total time=   0.0s
# [CV 1/5] END ......................solver=lbfgs;, score=0.797 total time=   0.0s
# [CV 2/5] END ......................solver=lbfgs;, score=0.772 total time=   0.0s
# [CV 3/5] END ......................solver=lbfgs;, score=0.835 total time=   0.0s
# [CV 4/5] END ......................solver=lbfgs;, score=0.782 total time=   0.0s
# [CV 5/5] END ......................solver=lbfgs;, score=0.679 total time=   0.0s
# [CV 1/5] END ..................solver=liblinear;, score=0.759 total time=   0.0s
# [CV 2/5] END ..................solver=liblinear;, score=0.747 total time=   0.0s
# [CV 3/5] END ..................solver=liblinear;, score=0.747 total time=   0.0s
# [CV 4/5] END ..................solver=liblinear;, score=0.756 total time=   0.0s
# [CV 5/5] END ..................solver=liblinear;, score=0.641 total time=   0.0s
# [CV 1/5] END ........................solver=sag;, score=0.797 total time=   0.0s
# [CV 2/5] END ........................solver=sag;, score=0.772 total time=   0.0s
# [CV 3/5] END ........................solver=sag;, score=0.835 total time=   0.0s
# [CV 4/5] END ........................solver=sag;, score=0.782 total time=   0.0s
# [CV 5/5] END ........................solver=sag;, score=0.679 total time=   0.0s
# [CV 1/5] END .......................solver=saga;, score=0.797 total time=   0.0s
# [CV 2/5] END .......................solver=saga;, score=0.785 total time=   0.0s
# [CV 3/5] END .......................solver=saga;, score=0.835 total time=   0.0s
# [CV 4/5] END .......................solver=saga;, score=0.782 total time=   0.0s
# [CV 5/5] END .......................solver=saga;, score=0.679 total time=   0.0s
# [CV 1/5] END ......................penalty=none;, score=0.772 total time=   0.0s
# [CV 2/5] END ......................penalty=none;, score=0.785 total time=   0.0s
# [CV 3/5] END ......................penalty=none;, score=0.835 total time=   0.0s
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning:
#
# `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning:
#
# `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning:
#
# `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning:
#
# `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning:
#
# `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
# [CV 4/5] END ......................penalty=none;, score=0.756 total time=   0.0s
# [CV 5/5] END ......................penalty=none;, score=0.718 total time=   0.0s
# [CV 1/5] END ..................penalty=elasticnet;, score=nan total time=   0.0s
# [CV 2/5] END ..................penalty=elasticnet;, score=nan total time=   0.0s
# [CV 3/5] END ..................penalty=elasticnet;, score=nan total time=   0.0s
# [CV 4/5] END ..................penalty=elasticnet;, score=nan total time=   0.0s
# [CV 5/5] END ..................penalty=elasticnet;, score=nan total time=   0.0s
# [CV 1/5] END ..........................penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END ..........................penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END ..........................penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END ..........................penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END ..........................penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ........................penalty=l2;, score=0.797 total time=   0.0s
# [CV 2/5] END ........................penalty=l2;, score=0.772 total time=   0.0s
# [CV 3/5] END ........................penalty=l2;, score=0.835 total time=   0.0s
# [CV 4/5] END ........................penalty=l2;, score=0.782 total time=   0.0s
# [CV 5/5] END ........................penalty=l2;, score=0.679 total time=   0.0s
# [CV 1/5] END ...........................C=0.001;, score=0.418 total time=   0.0s
# [CV 2/5] END ...........................C=0.001;, score=0.418 total time=   0.0s
# [CV 3/5] END ...........................C=0.001;, score=0.418 total time=   0.0s
# [CV 4/5] END ...........................C=0.001;, score=0.410 total time=   0.0s
# [CV 5/5] END ...........................C=0.001;, score=0.410 total time=   0.0s
# [CV 1/5] END ............................C=0.01;, score=0.418 total time=   0.0s
# [CV 2/5] END ............................C=0.01;, score=0.418 total time=   0.0s
# [CV 3/5] END ............................C=0.01;, score=0.418 total time=   0.0s
# [CV 4/5] END ............................C=0.01;, score=0.410 total time=   0.0s
# [CV 5/5] END ............................C=0.01;, score=0.410 total time=   0.0s
# [CV 1/5] END .............................C=0.1;, score=0.519 total time=   0.0s
# [CV 2/5] END .............................C=0.1;, score=0.519 total time=   0.0s
# [CV 3/5] END .............................C=0.1;, score=0.468 total time=   0.0s
# [CV 4/5] END .............................C=0.1;, score=0.462 total time=   0.0s
# [CV 5/5] END .............................C=0.1;, score=0.449 total time=   0.0s
# [CV 1/5] END ...............................C=1;, score=0.797 total time=   0.0s
# [CV 2/5] END ...............................C=1;, score=0.772 total time=   0.0s
# [CV 3/5] END ...............................C=1;, score=0.835 total time=   0.0s
# [CV 4/5] END ...............................C=1;, score=0.782 total time=   0.0s
# [CV 5/5] END ...............................C=1;, score=0.679 total time=   0.0s
# [CV 1/5] END ..............................C=10;, score=0.785 total time=   0.1s
# [CV 2/5] END ..............................C=10;, score=0.785 total time=   0.1s
# [CV 3/5] END ..............................C=10;, score=0.873 total time=   0.1s
# [CV 4/5] END ..............................C=10;, score=0.795 total time=   0.1s
# [CV 5/5] END ..............................C=10;, score=0.731 total time=   0.1s
# [CV 1/5] END .............................C=100;, score=0.823 total time=   0.1s
# [CV 2/5] END .............................C=100;, score=0.772 total time=   0.1s
# [CV 3/5] END .............................C=100;, score=0.835 total time=   0.1s
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
#
#
# 10 fits failed out of a total of 75.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning:
#
# One or more of the test scores are non-finite: [0.77332035 0.77332035 0.73012009 0.77332035 0.775852   0.77335281
#         nan        nan 0.77332035 0.41473548 0.41473548 0.4833171
#  0.77332035 0.7937358  0.78607595]
# [CV 4/5] END .............................C=100;, score=0.769 total time=   0.1s
# [CV 5/5] END .............................C=100;, score=0.731 total time=   0.1s
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']},
#                          {'penalty': ['none', 'elasticnet', 'l1', 'l2']},
#                          {'C': [0.001, 0.01, 0.1, 1, 10, 100]}],
#              verbose=3)

# %%
grid.score(X_test,y_test)
# Out:
# 0.7938931297709924

# %%
from sklearn.naive_bayes import MultinomialNB
model3=MultinomialNB()
model3.fit(X_train,y_train)
model3.score(X_test,y_test)
# Out:
# 0.7175572519083969

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
y_predicted=model.predict(X_test)
y_predicted2=model2.predict(X_test)
y_predicted3=model3.predict(X_test)

# %%
accuracy_score1=accuracy_score(y_predicted,y_test)
print(accuracy_score1)
accuracy_score2=accuracy_score(y_predicted2,y_test)
print(accuracy_score2)
accuracy_score3=accuracy_score(y_predicted3,y_test)
print(accuracy_score3)
# Out:
# 0.7786259541984732
# 0.7938931297709924
# 0.7175572519083969

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.59      0.73        34
#            1       0.86      0.70      0.77        43
#            2       0.69      0.96      0.81        54
#
#     accuracy                           0.78       131
#    macro avg       0.83      0.75      0.77       131
# weighted avg       0.81      0.78      0.77       131

# %%
print(classification_report(y_test, y_predicted2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72        34
#            1       0.86      0.74      0.80        43
#            2       0.75      0.93      0.83        54
#
#     accuracy                           0.79       131
#    macro avg       0.81      0.77      0.78       131
# weighted avg       0.80      0.79      0.79       131

# %%
print(classification_report(y_test, y_predicted3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.41      0.57        34
#            1       0.85      0.65      0.74        43
#            2       0.63      0.96      0.76        54
#
#     accuracy                           0.72       131
#    macro avg       0.80      0.68      0.69       131
# weighted avg       0.78      0.72      0.70       131

# %%
print(confusion_matrix(y_test, y_predicted))
# Out:
# [[20  3 11]
#  [ 1 30 12]
#  [ 0  2 52]]

# %%
print(confusion_matrix(y_test, y_predicted2))
# Out:
# [[22  3  9]
#  [ 3 32  8]
#  [ 2  2 50]]

# %%
print(confusion_matrix(y_test, y_predicted3))
# Out:
# [[14  3 17]
#  [ 1 28 14]
#  [ 0  2 52]]

# %%
print("best cross validation score: {:.4f}".format(grid.best_score_))
print("best parameters: ", grid.best_params_)
# Out:
# best cross validation score: 0.7937
# best parameters:  {'C': 10}

# %%
import seaborn as sb
cm2=confusion_matrix(y_test,y_predicted2)
sb.heatmap(cm2,annot=True)
plt.ylabel('Truth')
plt.xlabel('Predicted')
plt.figure(figsize=(10,7))

# %%
import pickle
with open('Sentiment_Analysis.pkl','wb') as file1:
    pickle.dump(model,file1)

# %%
with open('Sentiment_Analysis.pkl','rb') as file1:
    lmodel=pickle.load(file1)

# %%
dictionary={
    0:"negative",
    1:"positive",
    2:"neutral"
}

# %%
def model_predict(X):
  res=lmodel.predict(X_test[X])
  answer=dictionary[res[0]]
  print("The Sentiment Is : ",answer);

# %%
model_predict(100)
# Out:
# The Sentiment Is :  neutral

# %%
model_predict(10)
# Out:
# The Sentiment Is :  negative

# %%
model_predict(2)
# Out:
# The Sentiment Is :  neutral

# %%
model_predict(130)
# Out:
# The Sentiment Is :  positive
